# %% [markdown]
# # Basis Exploratory Data Analysis of Student grade dataset

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
read_student = pd.read_csv('student-mat.csv')

# %%
read_student.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
print('Total number of students:',len(read_student))
# Out:
# Total number of students: 395

# %%
read_student['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
b = sns.countplot(read_student['G3'])
b.axes.set_title('Distribution of Final grade of students', fontsize = 15)
b.set_xlabel('Final Grade', fontsize = 10)
b.set_ylabel('Count', fontsize = 10)
plt.show()

# %%
b = sns.countplot(read_student['reason'])
b.axes.set_title('Distribution of Reason to choose School', fontsize = 15)
b.set_xlabel('Reason', fontsize = 10)
b.set_ylabel('Count', fontsize = 10)
plt.show()

# %%
read_student.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
male_studs = len(read_student[read_student['sex'] == 'M'])
female_studs = len(read_student[read_student['sex'] == 'F'])
print('Number of male students:',male_studs)
print('Number of female students:',female_studs)
# Out:
# Number of male students: 187
# Number of female students: 208

# %%
b = sns.kdeplot(read_student['age'], shade=True)
b.axes.set_title('Ages of students', fontsize = 15)
b.set_xlabel('Age', fontsize = 10)
b.set_ylabel('Count', fontsize = 10)
plt.show()

# %%
b = sns.countplot('age',hue='sex', data=read_student)
b.axes.set_title('No of students in different age groups',fontsize=15)
b.set_xlabel("Age",fontsize=10)
b.set_ylabel("Count",fontsize=10)
plt.show()

# %%
b = sns.boxplot(x='age', y='G3', data=read_student)
b.axes.set_title('Age vs Final Grade', fontsize =25)
b.set_xlabel('Age', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()

# %% [markdown]
# # Grade distribution by address

# %%
# Grade distribution by address
sns.kdeplot(read_student.loc[read_student['address'] == 'U', 'G3'], label='Urban', shade = True, color="g")
sns.kdeplot(read_student.loc[read_student['address'] == 'R', 'G3'], label='Rural', shade = True, color="y")
#plt.title('Do urban students score higher than rural students?', fontsize = 15)
plt.xlabel('Grade', fontsize = 10);
plt.ylabel('Density', fontsize = 10)
plt.show()

# %%
b = sns.swarmplot(x='age', y='G3', data=read_student)
b.axes.set_title('Age vs Final grade', fontsize = 15)
b.set_xlabel('Age', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %%
b = sns.swarmplot(x='freetime', y='G3', data=read_student)
b.axes.set_title('Free Time vs Final grade', fontsize = 15)
b.set_xlabel('Free Time', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %%
b = sns.countplot(read_student['age'])
b.axes.set_title('Distribution of age of students', fontsize = 15)
b.set_xlabel('Age', fontsize = 10)
b.set_ylabel('Count', fontsize = 10)
plt.show()

# %%
b = sns.violinplot(x='famrel', y='G3', data=read_student, inner=None)
b = sns.swarmplot(x="famrel", y="G3", data=read_student, color="white", edgecolor="gray")
b.axes.set_title('Family Relationship vs Final grade of Students', fontsize = 15)
b.set_xlabel('Family Relationship', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %%
b = sns.violinplot(x='studytime', y='G3', data=read_student)
b.axes.set_title('Impact of Study time on Final grade of Students', fontsize = 13)
b.set_xlabel('Study Time', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %%
b = sns.violinplot(x='health', y='G3', data=read_student)
b.axes.set_title('Health vs Final grade', fontsize = 15)
b.set_xlabel('Health', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %%
b = sns.countplot(read_student['address'])
b.axes.set_title('Distribution of Urban and rural students', fontsize = 15)
b.set_xlabel('Address', fontsize = 10)
b.set_ylabel('Count', fontsize = 10)
plt.show()

# %%
# Grade distribution by address
sns.kdeplot(read_student.loc[read_student['address'] == 'U', 'G3'], label='Urban', shade = True)
sns.kdeplot(read_student.loc[read_student['address'] == 'R', 'G3'], label='Rural', shade = True)
plt.title('Do urban students score higher than rural students?', fontsize = 20)
plt.xlabel('Grade', fontsize = 20);
plt.ylabel('Density', fontsize = 20)
plt.show()

# %%
b = sns.countplot('failures',hue='sex', data=read_student)
#b.axes.set_title('Number of students in different age groups',fontsize=30)
b.set_xlabel("failures",fontsize=10)
b.set_ylabel("Count",fontsize=10)
plt.show()

# %%
sns.violinplot(x=read_student.traveltime, y=read_student.G3);

# %%
b = sns.countplot('romantic',hue='sex', data=read_student)
#b.axes.set_title('Number of students in different age groups',fontsize=30)
b.set_xlabel("Romantic",fontsize=10)
b.set_ylabel("Count",fontsize=10)
plt.show()

# %%
g = sns.catplot(x="Pstatus", y="G3",

               data=read_student, kind="bar")

# %%
b = sns.swarmplot(x=read_student['failures'],y=read_student['G3'])
b.axes.set_title('Students with less failures score higher', fontsize = 10)
b.set_xlabel('Number of failures', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %%
b = sns.swarmplot(x=read_student['romantic'],y=read_student['G3'])
b.axes.set_title('Students with no romantic relationship score higher', fontsize = 10)
b.set_xlabel('Romantic relationship (1 = None)', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %%
#read_student = read_student.dropna(how='any',axis=0)

read_student = read_student.loc[~(read_student==0).all(axis=1)]

# %%
read_student.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
b = sns.swarmplot(x=read_student['higher'],y=read_student['G3'])
#b.axes.set_title('Students with less failures score higher', fontsize = 10)
b.set_xlabel('Higher Education', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %%
b = sns.swarmplot(x=read_student['goout'],y=read_student['G3'])
#b.axes.set_title('Students who go out a lot score less', fontsize = 10)
b.set_xlabel('Going out', fontsize = 10)
b.set_ylabel('Final Grade', fontsize = 10)
plt.show()

# %% [markdown]
# # Now let's go ahead with the next analysis. We will opt for ensemble technique

# %% [markdown]
# The goal of ensemble methods is to combine the predictions of several base estimators built with a given learning algorithm in order to improve generalizability / robustness over a single estimator.

# %% [markdown]
# Our Target Variable (that is "y")

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Let's check the final grade ..

# %%
read_student['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
read_student.corr()['G3'].sort_values()
# Out:
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# Dalc         -0.054660
# Walc         -0.051939
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %%
read_student['sex'].describe()
# Out:
# count     395
# unique      2
# top         F
# freq      208
# Name: sex, dtype: object

# %% [markdown]
# # Let's encode our categorical variables

# %%
# Select only categorical variables
category_df = read_student.select_dtypes(include=['object'])

# One hot encode the variables
dummy_df = pd.get_dummies(category_df)

# Put the grade back in the dataframe
dummy_df['G3'] = read_student['G3']

# Find correlations with grade
dummy_df.corr()['G3'].sort_values()
# Out:
# higher_no           -0.182465
# romantic_yes        -0.129970
# Mjob_at_home        -0.115634
# address_R           -0.105756
# sex_F               -0.103456
# paid_no             -0.101996
# reason_course       -0.098950
# internet_no         -0.098483
# Mjob_other          -0.096477
# guardian_other      -0.087774
# schoolsup_yes       -0.082788
# famsize_GT3         -0.081407
# Pstatus_T           -0.058009
# Fjob_other          -0.053483
# nursery_no          -0.051568
# school_MS           -0.045017
# famsup_yes          -0.039157
# reason_home         -0.021359
# Fjob_services       -0.016108
# activities_no       -0.016100
# Fjob_at_home        -0.013385
# activities_yes       0.016100
# guardian_mother      0.022338
# guardian_father      0.032493
# famsup_no            0.039157
# school_GP            0.045017
# nursery_yes          0.051568
# reason_other         0.052008
# Fjob_health          0.057111
# Mjob_teacher         0.057712
# Pstatus_A            0.058009
# ...

# %%
b = sns.countplot(read_student['G3'])
b.axes.set_title('Distribution of Final grade of students', fontsize = 30)
b.set_xlabel('Final Grade', fontsize = 20)
b.set_ylabel('Count', fontsize = 20)
plt.show()

# %%
# selecting the most correlated values and dropping the others
labels = read_student['G3']

# drop the school and grade columns
read_student = read_student.drop(['school', 'G1', 'G2'], axis='columns')
    
# One-Hot Encoding of Categorical Variables
read_student = pd.get_dummies(read_student)

# %%
# Find correlations with the Grade
most_correlated = read_student.corr().abs()['G3'].sort_values(ascending=False)

# Maintain the top 8 most correlation features with Grade
most_correlated = most_correlated[:9]
most_correlated
# Out:
# G3             1.000000
# failures       0.360415
# Medu           0.217147
# higher_yes     0.182465
# higher_no      0.182465
# age            0.161579
# Fedu           0.152457
# goout          0.132791
# romantic_no    0.129970
# Name: G3, dtype: float64

# %%
read_student = read_student.loc[:, most_correlated.index]
read_student.head()
# Out:
#    G3  failures  Medu  higher_yes  higher_no  age  Fedu  goout  romantic_no
# 0   6         0     4           1          0   18     4      4            1
# 1   6         0     1           1          0   17     1      3            1
# 2  10         3     1           1          0   15     1      2            1
# 3  15         0     4           1          0   15     2      2            0
# 4  10         0     3           1          0   16     3      2            1

# %% [markdown]
# # Let's analyze these variables and build a model ..

# %%
b = sns.swarmplot(x=read_student['failures'],y=read_student['G3'])
b.axes.set_title('Students with less failures score higher', fontsize = 10)
b.set_xlabel('Number of failures', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()

# %% [markdown]
# #   Gradient Boosting Regressor (GBR) Ensemble technique

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(read_student,labels, test_size = 0.20, random_state=43)

# %%
X_train.head()
# Out:
#      G3  failures  Medu  higher_yes  higher_no  age  Fedu  goout  romantic_no
# 119  13         0     3           1          0   15     4      3            1
# 238  11         0     2           1          0   17     1      1            1
# 26   11         0     2           1          0   15     2      2            1
# 358  10         0     1           1          0   18     1      2            0
# 221   0         1     1           1          0   17     1      4            0

# %%
seed = 7
kfold = model_selection.KFold(n_splits=10, random_state=seed)
cart = DecisionTreeClassifier()
num_trees = 100
model = BaggingClassifier(base_estimator=cart, n_estimators=num_trees, random_state=seed)
results = model_selection.cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
